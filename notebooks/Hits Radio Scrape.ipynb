# %% [markdown]
# ## HITS RADIO SCRAP

# %% [markdown]
# - In this project, I'll be scraping Top songs on Hits Radio website: https://onlineradiobox.com/ke/hitskenya/.
# - I'll be scraping the song name, artist name then searching the songs on spotify and generating a Playlist.
# - I'll be using BeautifulSoup and requests libraries to scrape the website.

# %% [markdown]
# ### Import libraries

# %%
from bs4 import BeautifulSoup
import requests as re
import csv
import os
from datetime import datetime

# %% [markdown]
# ### Scrap website

# %%
# Hits Radio Playlist URL
url = 'https://onlineradiobox.com/ke/hitskenya/playlist/?cs=ke.xfmkenya'

# Requests to fetch tge url
html = re.get(url).text

# Parse the Url to BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# ### Find songs and time

# %%
# Here I use the class name 'ajax' to find the songs
songs = soup.find_all('a', class_='ajax')

# Here I use the class name 'time--schedule' to find the time it was played
time = soup.find_all('span', class_='time--schedule')

# %% [markdown]
# ### Get tracks and Get time functions

# %%
# I then develop a function to get the tracks and strip the href
def get_tracks(soup):
    tracks = soup.find_all('a', class_='ajax', href=lambda x: x and x.startswith('/track'))
    return tracks
tracks = get_tracks(soup)

# Function to get time
def get_time(soup):
    time = soup.find_all('span', class_='time--schedule')
    return time
time = get_time(soup)

# %% [markdown]
# ### Iterate though the get_tracks and get_time function to print corresponding Tracks, Time and Track ID

# %%
# Create an empty list to store track details
track_list = []

# Loop through each track and its corresponding time
for track, t in zip(get_tracks(soup), get_time(soup)):  # Zip combines the track and t(time) elements pairwise
    track_title = track.text.strip()  # Extract track title
    track_href = track.get('href')  # Extract the href link
    track_id = track_href.split('/track/')[-1].strip('/')  # Extract track ID
    time = t.text.strip()  # Extract time

    # Store details in a dictionary and append to list
    track_list.append({
        "Time": time,
        "Track Title": track_title,
        "Track ID": track_id
    })

# Print the stored list (optional)
print(track_list)
# Out:
# [{'Time': 'Live', 'Track Title': 'Steel Banglez - Steel Banglez Fashion Week feat. AJ Tracey MoStack', 'Track ID': '1170572833495223199'}, {'Time': '14:17', 'Track Title': 'YFN Lucci - Both Of Us (feat. Rick Ross Layton Greene)', 'Track ID': '1891131398208258811'}, {'Time': '14:15', 'Track Title': 'KYLE - Optimistic (feat Dougie F)', 'Track ID': '1620510901518302452'}, {'Time': '14:11', 'Track Title': 'Dexta Daps - Wifi (TTRR )', 'Track ID': '432422557519354042'}, {'Time': '14:09', 'Track Title': 'Marshmello x Jonas Brothers - Leave Before You Love Me', 'Track ID': '1963171460897387007'}, {'Time': '14:05', 'Track Title': 'Falz Kamo Mphela Mpura - Squander (Remix) ft. Sayfar', 'Track ID': '1819056258839334610'}, {'Time': '14:02', 'Track Title': 'Mooski - Soul Bleed Clean', 'Track ID': '1242595616819564349'}, {'Time': '14:02', 'Track Title': 'Clean Bandit and Mabel - Tick Tock (feat. 24kGoldn)', 'Track ID': '1602900985190016573'}, {'Time': '12:58', 'Track Title': 'Justin Bieber - Justin Bieber - Peaches ft. Daniel Caesar Giveon', 'Track ID': '1225073683077330439'}, {'Time': '12:55', 'Track Title': '24kGoldn feat. iann dior - Mood (Replay M Remix)', 'Track ID': '432528090102803045'}, {'Time': '12:52', 'Track Title': 'Conan Gray - Overdrive', 'Track ID': '395549266102352470'}, {'Time': '12:46', 'Track Title': 'Hardy Caprio - Under The Sun (Lyrics) feat. T Mulla', 'Track ID': '1116107847595107058'}, {'Time': '12:43', 'Track Title': 'CLEAN Lil Baby - On Me (Remix) (with Megan Thee Stallion)', 'Track ID': '2089712045177171422'}, {'Time': '12:41', 'Track Title': 'KSHMR - Around The World (Feat. NOUMENN)', 'Track ID': '648595315295068503'}, {'Time': '12:38', 'Track Title': 'Nyashinski - Hapo Tu ft Chris Kaiga SMS Skiza 7301588 to 811 filename=utf-8 Nyashinski - Hapo Tu ft Chris Kaiga SMS Skiza 7301588 to 811', 'Track ID': '2124949153049123687'}, {'Time': '12:35', 'Track Title': 'ROSALÍA Travis Scott - TKN (Luca Montez Remix)', 'Track ID': '1153103947352588482'}, {'Time': '12:32', 'Track Title': 'MAANDY X BREEDER LW X NDOVU KUU - Sirudi Home Remix', 'Track ID': '1620545988943152047'}, {'Time': '12:29', 'Track Title': 'Bruce Melodie - Katapilla Extended Merlin Xyendz', 'Track ID': '1620510886480009821'}, {'Time': '12:26', 'Track Title': 'Headie One - 2 Chains', 'Track ID': '323474201302370008'}, {'Time': '12:22', 'Track Title': 'CKay - Love Nwantiti Remix ft. Joeboy Kuami Eugene Ah Ah Ah', 'Track ID': '89673849342584826'}, {'Time': '12:18', 'Track Title': 'Juno Kizigenza - Nazubaye (Audio)', 'Track ID': '1620510846281812795'}, {'Time': '12:15', 'Track Title': 'Yellow Claw - Baila Conmigo', 'Track ID': '1386728073994637716'}, {'Time': '12:11', 'Track Title': 'SJUR ft. Chris Crone - Let Me Love You', 'Track ID': '2179343722033371968'}, {'Time': '12:08', 'Track Title': 'DJ Khaled - LET IT GO (feat. Justin Bieber & 21 Savage)', 'Track ID': '1314653105839000456'}, {'Time': '12:05', 'Track Title': 'Chris Brown Tyga - Ayo (Alessandro Di Lorenzo x Tyb Remix)', 'Track ID': '648894094109962382'}, {'Time': '12:01', 'Track Title': 'Ty Dolla $ign Ft. J Balvin YG Tyga Post Malone - Spicy Remix', 'Track ID': '2269046761004438854'}, {'Time': '11:58', 'Track Title': 'Tion Wayne - Who s True Ft Davido (Audio)', 'Track ID': '1369118404603300052'}, {'Time': '11:54', 'Track Title': 'Million Stylez - Miss Fatty (Max Wallin Remix)', 'Track ID': '792815564432224548'}, {'Time': '11:49', 'Track Title': 'Official Clean DJ Khaled - EVERY CHANCE I GET (feat. Lil Baby Lil Durk)', 'Track ID': '360400158064801252'}, {'Time': '11:49', 'Track Title': 'Mayorkun - Certified Loner (No Competition)', 'Track ID': '449979715406111499'}, {'Time': '11:45', 'Track Title': 'BIA - WHOLE LOTTA MONEY (Remix) (feat. Nicki Minaj)', 'Track ID': '233789163533984529'}, {'Time': '11:45', 'Track Title': 'DJ Maphorisa Tyler ICU - Banyana ft. Sir Trill Daliwonga Kabza De Small', 'Track ID': '1026422745847563060'}, {'Time': '11:42', 'Track Title': 'Azawi - Party Mood', 'Track ID': '10264228096 ...

# %%
# Loop through the list of track details and print each track
for track in track_list:
    print(track)
# Out:
# {'Time': 'Live', 'Track Title': 'Steel Banglez - Steel Banglez Fashion Week feat. AJ Tracey MoStack', 'Track ID': '1170572833495223199'}
# {'Time': '14:17', 'Track Title': 'YFN Lucci - Both Of Us (feat. Rick Ross Layton Greene)', 'Track ID': '1891131398208258811'}
# {'Time': '14:15', 'Track Title': 'KYLE - Optimistic (feat Dougie F)', 'Track ID': '1620510901518302452'}
# {'Time': '14:11', 'Track Title': 'Dexta Daps - Wifi (TTRR )', 'Track ID': '432422557519354042'}
# {'Time': '14:09', 'Track Title': 'Marshmello x Jonas Brothers - Leave Before You Love Me', 'Track ID': '1963171460897387007'}
# {'Time': '14:05', 'Track Title': 'Falz Kamo Mphela Mpura - Squander (Remix) ft. Sayfar', 'Track ID': '1819056258839334610'}
# {'Time': '14:02', 'Track Title': 'Mooski - Soul Bleed Clean', 'Track ID': '1242595616819564349'}
# {'Time': '14:02', 'Track Title': 'Clean Bandit and Mabel - Tick Tock (feat. 24kGoldn)', 'Track ID': '1602900985190016573'}
# {'Time': '12:58', 'Track Title': 'Justin Bieber - Justin Bieber - Peaches ft. Daniel Caesar Giveon', 'Track ID': '1225073683077330439'}
# {'Time': '12:55', 'Track Title': '24kGoldn feat. iann dior - Mood (Replay M Remix)', 'Track ID': '432528090102803045'}
# {'Time': '12:52', 'Track Title': 'Conan Gray - Overdrive', 'Track ID': '395549266102352470'}
# {'Time': '12:46', 'Track Title': 'Hardy Caprio - Under The Sun (Lyrics) feat. T Mulla', 'Track ID': '1116107847595107058'}
# {'Time': '12:43', 'Track Title': 'CLEAN Lil Baby - On Me (Remix) (with Megan Thee Stallion)', 'Track ID': '2089712045177171422'}
# {'Time': '12:41', 'Track Title': 'KSHMR - Around The World (Feat. NOUMENN)', 'Track ID': '648595315295068503'}
# {'Time': '12:38', 'Track Title': 'Nyashinski - Hapo Tu ft Chris Kaiga SMS Skiza 7301588 to 811 filename=utf-8 Nyashinski - Hapo Tu ft Chris Kaiga SMS Skiza 7301588 to 811', 'Track ID': '2124949153049123687'}
# {'Time': '12:35', 'Track Title': 'ROSALÍA Travis Scott - TKN (Luca Montez Remix)', 'Track ID': '1153103947352588482'}
# {'Time': '12:32', 'Track Title': 'MAANDY X BREEDER LW X NDOVU KUU - Sirudi Home Remix', 'Track ID': '1620545988943152047'}
# {'Time': '12:29', 'Track Title': 'Bruce Melodie - Katapilla Extended Merlin Xyendz', 'Track ID': '1620510886480009821'}
# {'Time': '12:26', 'Track Title': 'Headie One - 2 Chains', 'Track ID': '323474201302370008'}
# {'Time': '12:22', 'Track Title': 'CKay - Love Nwantiti Remix ft. Joeboy Kuami Eugene Ah Ah Ah', 'Track ID': '89673849342584826'}
# {'Time': '12:18', 'Track Title': 'Juno Kizigenza - Nazubaye (Audio)', 'Track ID': '1620510846281812795'}
# {'Time': '12:15', 'Track Title': 'Yellow Claw - Baila Conmigo', 'Track ID': '1386728073994637716'}
# {'Time': '12:11', 'Track Title': 'SJUR ft. Chris Crone - Let Me Love You', 'Track ID': '2179343722033371968'}
# {'Time': '12:08', 'Track Title': 'DJ Khaled - LET IT GO (feat. Justin Bieber & 21 Savage)', 'Track ID': '1314653105839000456'}
# {'Time': '12:05', 'Track Title': 'Chris Brown Tyga - Ayo (Alessandro Di Lorenzo x Tyb Remix)', 'Track ID': '648894094109962382'}
# {'Time': '12:01', 'Track Title': 'Ty Dolla $ign Ft. J Balvin YG Tyga Post Malone - Spicy Remix', 'Track ID': '2269046761004438854'}
# {'Time': '11:58', 'Track Title': 'Tion Wayne - Who s True Ft Davido (Audio)', 'Track ID': '1369118404603300052'}
# {'Time': '11:54', 'Track Title': 'Million Stylez - Miss Fatty (Max Wallin Remix)', 'Track ID': '792815564432224548'}
# {'Time': '11:49', 'Track Title': 'Official Clean DJ Khaled - EVERY CHANCE I GET (feat. Lil Baby Lil Durk)', 'Track ID': '360400158064801252'}
# {'Time': '11:49', 'Track Title': 'Mayorkun - Certified Loner (No Competition)', 'Track ID': '449979715406111499'}
# {'Time': '11:45', 'Track Title': 'BIA - WHOLE LOTTA MONEY (Remix) (feat. Nicki Minaj)', 'Track ID': '233789163533984529'}
# {'Time': '11:45', 'Track Title': 'DJ Maphorisa Tyler ICU - Banyana ft. Sir Trill Daliwonga Kabza De Small', 'Track ID': '1026422745847563060'}
# {'Time': '11:42', 'Track Title': 'Azawi - Party Mood', 'Track ID': '1026422809628104672'}
# {'Time': '11:38', 'Track Title': 'Magixx - Love Don t Cost A Dime (Re-up) feat. Ayra Starr', 'Track ID': '1153104177951880888'}
# {'Time': '11:35', 'Track Title': 'Stay Flee Get Lizzy feat. Fredo Central Cee - Meant To Be', 'Track ID': '1026440333793374545'}
# {'Time': '11:32', 'Track Title': 'Anne-Marie Little Mix - Kiss My (Uh Oh) Girl Power Remix feat. Becky Hill RAYE Stefflon', 'Track ID': '1729424113269515340'}
# {'Time': '11:28', 'Track Title': 'Cuppy - Feel Good ft. Fireboy DML', 'Track ID': '1674940987660964389'}
# {'Time': '11:24', 'Track Title': 'Tion Wayne x Russ Millions - Body 2 ft Arrdee 3x3E1 ZT Bugzy Malone Fivio Foreign Darkoo', 'Track ID': '1963189055843592338'}
# {'Time': '11:21', 'Track Title': 'Raphael Lake Eric Brooks Camden Rose - In My Atmosphere (Virgin River OST)', 'Track ID': '2268993853124465206'}
# {'Time': '11:21', 'Track Title': 'DaBaby - Lonely (with Lil Wayne)', 'Track ID': '1297201074032625730'}
# {'Time': '11:18', 'Track Title': 'Dj Neptune ft Mr Eazi & Konshens - Dj Neptune ft Mr Eazi & Konshens – WALANGOLO', 'Track ID': '899952625629130328'}
# {'Time': '11:18', 'Track Title': 'King Promise ft. Headie One - Ring My Line', 'Track ID': '1369188923702462774'}
# {'Time': '11:15', 'Track Title': 'Smallgod Ft Tiwa Savage Kwesi Arthur - Let Dem Kno', 'Track ID': '1548453276358880072'}
# {'Time': '11:10', 'Track Title': 'Ali Gatie - What If I Told You That I Love You (Lyrics)', 'Track ID': '1585343909138889425'}
# {'Time': '11:08', 'Track Title': 'CLEAN Jack Harlow - Nail Tech', 'Track ID': '2269046893860848618'}
# {'Time': '11:03', 'Track Title': 'Burna Boy - Vanilla', 'Track ID': '144420774984601335'}
# {'Time': '10:59', 'Track Title': 'Shakka - Doin Time ft. Imani', 'Track ID': '648630595257157098'}
# {'Time': '10:52', 'Track Title': 'benny blanco Marshmello Vance Joy - You (Official Visualizer)', 'Track ID': '1188165312557624721'}
# {'Time': '10:49', 'Track Title': 'Yxng Bane - Birthday ft. Stefflon Don', 'Track ID': '1297078529084250095'}
# {'Time': '10:45', 'Track Title': 'Simi - So Bad ft. Joeboy', 'Track ID': '2035264039779028379'}
# {'Time': '10:42', 'Track Title': 'The Kid LAROI Justin Bieber - Stay', 'Track ID': '2161910364355139336'}
# {'Time': '10:39', 'Track Title': 'Dj Rebel Mohombi Shaggy - let me love you (hq)', 'Track ID': '648577127457533242'}
# {'Time': '10:39', 'Track Title': 'Drake ft. Future and Young Thug - Way 2 Sexy', 'Track ID': '1963189088565598883'}
# {'Time': '10:36', 'Track Title': 'Kris Kross Amsterdam - Early In The Morning ft. Shaggy Conor Maynard', 'Track ID': '2017707223863844793'}
# {'Time': '10:32', 'Track Title': 'Lil Baby - Lil Baby - On Me (Remix) (with Megan Thee Stallion)', 'Track ID': '1170555472874663532'}
# {'Time': '10:30', 'Track Title': 'Mr Eazi Major Lazer feat. Nicki Minaj K4mo - Oh My Gawd (SABER x FRAZE Remix)', 'Track ID': '1585344030912810395'}
# {'Time': '10:26', 'Track Title': 'Adekunle Gold Lucky Daye - Sinner', 'Track ID': '144192216192520664'}
# {'Time': '10:23', 'Track Title': 'Tory Lanez - It Doesn t Matter', 'Track ID': '233789331274810305'}
# {'Time': '10:20', 'Track Title': 'Ally Brooke - Lips Don t Lie (feat. A Boogie Wit Da Hoodie) (R3HAB Remix)', 'Track ID': '161766550010927911'}
# {'Time': '10:17', 'Track Title': 'Melano Blac X AdeJosh - Jollof (Official Visualizer)', 'Track ID': '35243886401023892'}
# {'Time': '10:14', 'Track Title': 'Ariana Grande - 34 35 (Onderkoffer Remix)', 'Track ID': '377904345929313862'}
# {'Time': '10:11', 'Track Title': 'Lie To Me - Karun Blocka Beats', 'Track ID': '971992676707489261'}
# {'Time': '10:07', 'Track Title': 'Spice ft. Sean Paul Shaggy - Go Down Deh', 'Track ID': '233806790042838763'}
# {'Time': '10:04', 'Track Title': 'Sauti Sol - Still The One', 'Track ID': '1441263483850791778'}
# {'Time': '10:02', 'Track Title': 'Aya Nakamura - Bobo', 'Track ID': '449979378658630734'}
# {'Time': '09:58', 'Track Title': 'Don t Clean - Bryson Tiller', 'Track ID': '666134831798028050'}
# {'Time': '09:55', 'Track Title': 'ZieZie - Blessed G46 GRIME', 'Track ID': '738192331242851678'}
# {'Time': '09:52', 'Track Title': 'Wes Nelson - Nice To Meet Ya (Lyrics) ft Yxng Bane', 'Track ID': '449979559122487605'}
# {'Time': '09:26', 'Track Title': 'Cheat Codes - Do It All Over (feat. Marc E. Bassy)', 'Track ID': '1152998456193454283'}
# {'Time': '09:23', 'Track Title': 'Diamond Platnumz ft Focalistic Costa Titch Pabi Cooper - Fresh (', 'Track ID': '2269029313849538892'}
# {'Time': '09:20', 'Track Title': 'One Acen - Monogram ft. Wauve', 'Track ID': '1441228879897058741'}
# {'Time': '09:17', 'Track Title': 'Adekunle Gold - Okay (Afro Pop Vol. 1)', 'Track ID': '2161857512078794801'}
# {'Time': '09:14', 'Track Title': 'Rema - Bounce', 'Track ID': '1152998485684728645'}
# {'Time': '09:11', 'Track Title': 'NSG Ft. LD - Roadblock', 'Track ID': '35243914392981027'}
# {'Time': '09:07', 'Track Title': 'Fireboy DML Ed Sheeran - Peru', 'Track ID': '1332315694376141878'}
# {'Time': '09:03', 'Track Title': 'D-Block Europe - Ferrari Horses ft. Raye', 'Track ID': '810267521133078020'}
# {'Time': '09:00', 'Track Title': 'Ariana Grande - One last time (Amapiano Remix)By La Mayor', 'Track ID': '738209730336986045'}
# {'Time': '08:57', 'Track Title': 'Stefflon Don - Can t Let You Go (Lyrics)', 'Track ID': '1458768225231569454'}
# {'Time': '08:54', 'Track Title': 'Yxng Bane ft. WSTRN - Fine Wine (Remix) GRM Daily', 'Track ID': '899934666598389685'}
# {'Time': '08:50', 'Track Title': 'Headie One - Siberia ft. Burna Boy', 'Track ID': '2161787198462941046'}
# {'Time': '08:47', 'Track Title': 'Wauve - Monzo ft. One Acen', 'Track ID': '1980798877648308356'}
# {'Time': '08:40', 'Track Title': 'Bayanni - Ta Ta Ta (Official Lyric Audio)', 'Track ID': '1332315832514073544'}
# {'Time': '08:37', 'Track Title': 'Maroon 5 - Beautiful Mistakes ft. Megan Thee Stallion', 'Track ID': '216284949413964196'}
# {'Time': '08:33', 'Track Title': 'DJ Snake Ozuna Megan Thee Stallion LISA of BLACKPINK - SG.wav', 'Track ID': '89691660975184574'}
# {'Time': '08:30', 'Track Title': 'Rema - Soundgasm (MAX WALLIN TOUCH)', 'Track ID': '1729424187542879007'}
# {'Time': '08:26', 'Track Title': 'Jocelyn Alice - Feels Right (Galloway Remix)', 'Track ID': '1225108262845568025'}
# {'Time': '08:23', 'Track Title': 'City Girls Fivio Foreign - Top Notch', 'Track ID': '2017707347510678428'}
# {'Time': '08:19', 'Track Title': 'Dave Stormzy - Clash', 'Track ID': '1945737621074297053'}
# {'Time': '08:19', 'Track Title': 'Lauv - 26', 'Track ID': '2052926881562397537'}
# {'Time': '08:14', 'Track Title': 'Major Lazer - C est Cuit (feat. Aya Nakamura Swae Lee)', 'Track ID': '738209940860823708'}
# {'Time': '08:11', 'Track Title': 'Blaq Diamond - SummerYoMuthi', 'Track ID': '233789136301771862'}
# {'Time': '08:09', 'Track Title': 'INNA - Always On My Mind (Lyrics)', 'Track ID': '1225144151901805036'}
# {'Time': '08:04', 'Track Title': '24kGoldn - Coco (Clean Lyrics) ft. DaBaby', 'Track ID': '377921972735235795'}
# {'Time': '08:01', 'Track Title': 'Tems- The Key', 'Track ID': '2197006731049085016'}
# {'Time': '07:14', 'Track Title': 'Davido - Jowo NR Xtendz', 'Track ID': '1152998448626177596'}
# {'Time': '07:14', 'Track Title': 'Sauti Sol - Rhumba Japani ft Kaskazini Bensoul Nviiri Xenia Manasseh Okello Max Nairobi Ho', 'Track ID': '1602900993913347031'}
# {'Time': '07:11', 'Track Title': 'Diane Warren Rita Ora Sofía Reyes Reik - Seaside', 'Track ID': '2035246685143211178'}
# {'Time': '07:09', 'Track Title': 'WizKid - Essence (Audio) ft. Tems', 'Track ID': '467624467706850916'}
# {'Time': '07:05', 'Track Title': 'J.Derobie Gold Up - Day Night Official Lyrics Video', 'Track ID': '1332280454922988574'}
# {'Time': '07:01', 'Track Title': 'Bensoul x Bien - Thick Thighs', 'Track ID': '179359070883021097'}
# {'Time': '06:57', 'Track Title': 'Ava Max - My Head My Heart', 'Track ID': '216548825543248714'}
# {'Time': '06:57', 'Track Title': 'MIST feat Burna Boy - Rollin', 'Track ID': '1980834027270609897'}
# {'Time': '06:54', 'Track Title': 'DJ Snake Selena Gomez - Selfish Love (Lyrics )', 'Track ID': '1891131433735687053'}
# {'Time': '06:51', 'Track Title': 'Darkoo - Rover (Keys to my rover)', 'Track ID': '1404337881203476442'}
# {'Time': '06:47', 'Track Title': 'M.anifest - Game Over ft. Adekunle Gold', 'Track ID': '1513268976329909555'}
# {'Time': '06:44', 'Track Title': 'Doja Cat - Woman (Mica Remix)', 'Track ID': '1153016144237692820'}
# {'Time': '06:42', 'Track Title': 'Headie One - Everything Nice (feat. Haile) G46 GRIME', 'Track ID': '467589369385754801'}
# {'Time': '06:37', 'Track Title': 'MAGGIE WA NYUMBANI - NDOVU KUU X BIEN THE BALDMAN', 'Track ID': '161731742428978777'}
# {'Time': '06:21', 'Track Title': 'Black Sherif - Kwaku The Traveller (Radio Clean)', 'Track ID': '1513251417634161738'}
# {'Time': '06:18', 'Track Title': 'CLEAN Central Cee - Khabib', 'Track ID': '539647043043446252'}
# {'Time': '06:18', 'Track Title': 'Major Lazer feat. Alessia Cara - Hell and High Water', 'Track ID': '1026440254678705995'}
# {'Time': '06:16', 'Track Title': 'Galantis x Throttle - Tell Me You Love Me', 'Track ID': '1170537471180084891'}
# {'Time': '06:13', 'Track Title': 'Adekunle Gold - It Is What It Is', 'Track ID': '1441193699923542436'}
# {'Time': '06:10', 'Track Title': 'Joeboy - Contour (Lyric Visualizer)', 'Track ID': '2269029366337962777'}
# {'Time': '06:06', 'Track Title': 'Mannywellz ft Tems - Peace (Lyrics)', 'Track ID': '1801516789807321156'}
# {'Time': '06:03', 'Track Title': 'Chunkz X Filly - Hold', 'Track ID': '899934842125741527'}
# {'Time': '05:58', 'Track Title': 'Kizz Daniel - Pour Me Water', 'Track ID': '666134364759668160'}
# {'Time': '05:55', 'Track Title': '21 Savage Metro Boomin - Runnin (Clean - Lyrics)', 'Track ID': '1746998679007075883'}
# {'Time': '05:52', 'Track Title': 'Oxlade - Ojuju', 'Track ID': '323474196019600280'}
# {'Time': '05:49', 'Track Title': 'King Promise - Sisa', 'Track ID': '2251436859012401176'}
# {'Time': '05:47', 'Track Title': 'Calvin Harris Dua Lipa Young Thug - Potion', 'Track ID': '1746998808420683773'}
# {'Time': '05:44', 'Track Title': 'Mary-J-Blige- Without You (Wallies Amapiano Remix)', 'Track ID': '94441134465316'}
# {'Time': '05:41', 'Track Title': 'DJ Neptune - Hustle (feat. Focalistic)', 'Track ID': '2035246722780376548'}
# {'Time': '05:37', 'Track Title': 'Mr Eazi - Cherry (feat. Xenia Manasseh)', 'Track ID': '2196971582864756533'}
# {'Time': '05:35', 'Track Title': 'BNXN fka Buju - In My Mind', 'Track ID': '1657401837910154837'}
# {'Time': '05:31', 'Track Title': 'Chris Kaiga - MAJALIWA feat. Fena Gitu', 'Track ID': '827877464011011151'}
# {'Time': '05:27', 'Track Title': 'BackRoad Gee - Nyege Lewa Ft. Ms Banks', 'Track ID': '2124914094250016190'}
# {'Time': '05:24', 'Track Title': 'Tyla Yaweh - All The Smoke (Clean Lyrics) ft. Gunna Wiz Khalifa', 'Track ID': '504585689927075872'}
# {'Time': '05:21', 'Track Title': 'Ruger Midas The Jagaban - Bounce (UK Remix - Visualiser)', 'Track ID': '467589331490212822'}
# {'Time': '05:18', 'Track Title': 'Belly - Better Believe (feat. The Weeknd & Young Thug)', 'Track ID': '594094786699759679'}
# {'Time': '05:15', 'Track Title': 'Headie One - Siberia ft. Burna Boy', 'Track ID': '2161787198462941046'}
# {'Time': '05:12', 'Track Title': 'Raphael Lake Eric Brooks Camden Rose - In My Atmosphere (Virgin River OST)', 'Track ID': '2268993853124465206'}
# {'Time': '05:09', 'Track Title': 'Rema - Bounce', 'Track ID': '1152998485684728645'}
# {'Time': '05:06', 'Track Title': 'Skales - Badman Love (Remix) ft Tekno', 'Track ID': '1548453216571186777'}
# {'Time': '05:03', 'Track Title': 'Maud Elka feat Alikiba - Songi Songi Remix', 'Track ID': '1170537960281429253'}
# {'Time': '05:00', 'Track Title': 'N-Dubz - Charmer', 'Track ID': '937089403238122204'}
# {'Time': '04:57', 'Track Title': 'DJ Maphorisa Tyler ICU - Banyana ft. Sir Trill Daliwonga Kabza De Small', 'Track ID': '1026422745847563060'}
# {'Time': '04:53', 'Track Title': 'Stefflon Don - Move', 'Track ID': '1225108638756689441'}
# {'Time': '04:50', 'Track Title': 'Kizz Daniel Tekno - Buga', 'Track ID': '792710350993250986'}
# {'Time': '04:46', 'Track Title': 'Future Lil Uzi Vert - Drankin N Smokin', 'Track ID': '864803192441923648'}
# {'Time': '04:39', 'Track Title': 'Central Cee - Commitment Issues', 'Track ID': '666152323906101324'}
# {'Time': '04:35', 'Track Title': 'King Promise - Ginger', 'Track ID': '467589478561255739'}
# {'Time': '04:33', 'Track Title': 'Bruce Melodie - Katapilla Extended Merlin Xyendz', 'Track ID': '1620510886480009821'}
# {'Time': '04:31', 'Track Title': 'BNXN fka Buju - In My Mind', 'Track ID': '1657401837910154837'}
# {'Time': '04:28', 'Track Title': 'Fireboy DML - Energy (Audio)', 'Track ID': '2251436897152469517'}
# {'Time': '04:25', 'Track Title': 'Diamond Platnumz - Naanzaje', 'Track ID': '1476395600164439525'}
# {'Time': '04:21', 'Track Title': 'CLEAN Fivio Foreign Kanye West Alicia Keys - City of Gods', 'Track ID': '1548453383088909238'}
# {'Time': '04:18', 'Track Title': 'Nyashinski - Hapo Tu ft Chris Kaiga SMS Skiza 7301588 to 811 filename=utf-8 Nyashinski - Hapo Tu ft Chris Kaiga SMS Skiza 7301588 to 811', 'Track ID': '2124949153049123687'}
# {'Time': '04:15', 'Track Title': 'Burna Boy - Vanilla', 'Track ID': '144420774984601335'}
# {'Time': '04:12', 'Track Title': '@KiDi x @Tyga - Touch It', 'Track ID': '1873556959581144156'}
# {'Time': '04:08', 'Track Title': 'Conan Gray - Overdrive', 'Track ID': '395549266102352470'}
# {'Time': '04:05', 'Track Title': 'Blaq Jerzee Mr Eazi Harmonize - Falling For U', 'Track ID': '107301359739439618'}
# {'Time': '04:02', 'Track Title': 'Fireboy DML Ed Sheeran - Peru', 'Track ID': '1332315694376141878'}
# {'Time': '03:59', 'Track Title': 'Young T Bugsey - Don t Rush (ft. Headie One) GRM Daily', 'Track ID': '467624283425513091'}
# {'Time': '03:54', 'Track Title': 'Headie One - 2 Chains', 'Track ID': '323474201302370008'}
# {'Time': '03:51', 'Track Title': 'Joeboy - Alcohol', 'Track ID': '1116107746176803314'}
# {'Time': '03:47', 'Track Title': 'Joeboy - Likkle Riddim', 'Track ID': '17634190647024101'}
# {'Time': '03:44', 'Track Title': 'melvitto Gabzy - 4 Nothin', 'Track ID': '2124949026970711575'}
# {'Time': '03:41', 'Track Title': 'Aya Nakamura - Djadja (Dj BraindeaD x Dutty Nation Remix)', 'Track ID': '2089729485214650263'}
# {'Time': '03:38', 'Track Title': 'Charlie Puth - Light Switch', 'Track ID': '360400251730625971'}
# {'Time': '03:35', 'Track Title': 'Tate McRae - bad ones (Lyrics)', 'Track ID': '720652931281822128'}
# {'Time': '03:32', 'Track Title': 'Beach Boii - Rude (Buskilaz Remix)', 'Track ID': '576554938102348913'}
# {'Time': '03:27', 'Track Title': 'Belly Squad - Unknown Number GRM Daily', 'Track ID': '539646862019770422'}
# {'Time': '03:27', 'Track Title': 'Mannywellz ft Tems - Peace (Lyrics)', 'Track ID': '1801516789807321156'}
# {'Time': '03:25', 'Track Title': 'Robin Schulz feat. KIDDO - All We Got', 'Track ID': '1009147133195343594'}
# {'Time': '03:25', 'Track Title': 'DJ Tunez Wizkid - Cool Me Down', 'Track ID': '2052891505932983749'}
# {'Time': '03:21', 'Track Title': 'Major Lazer - Titans (feat. Sia & Labrinth)', 'Track ID': '683762118386080542'}
# {'Time': '03:18', 'Track Title': 'Asake - Sungba (Remix) (feat. Burna Boy)', 'Track ID': '1764626160997944959'}
# {'Time': '03:14', 'Track Title': 'Chris Brown Tyga - Ayo (Alessandro Di Lorenzo x Tyb Remix)', 'Track ID': '648894094109962382'}
# {'Time': '03:11', 'Track Title': 'DJ Khaled - LET IT GO (feat. Justin Bieber & 21 Savage)', 'Track ID': '1314653105839000456'}
# {'Time': '03:08', 'Track Title': 'Dolapo Ms Banks Oxlade - Interest', 'Track ID': '2161910342694604923'}
# {'Time': '03:05', 'Track Title': 'Saweetie - Closer (feat. H.E.R.) (Lyrics) (Closer Clean)', 'Track ID': '2251401929646133089'}
# {'Time': '03:02', 'Track Title': 'LADIPOE - Feeling (feat. Buju)', 'Track ID': '77005815216121'}
# {'Time': '02:59', 'Track Title': 'Diamond Platnumz ft Focalistic Costa Titch Pabi Cooper - Fresh (', 'Track ID': '2269029313849538892'}
# {'Time': '02:56', 'Track Title': 'Internet Money - JETSKI ( Lyrics) feat. Lil Mosey Lil Tecca', 'Track ID': '1116125255325626803'}
# {'Time': '02:52', 'Track Title': 'Jux - Simuachi', 'Track ID': '323474291335011208'}
# {'Time': '02:52', 'Track Title': 'Drake ft. Future and Young Thug - Way 2 Sexy', 'Track ID': '1963189088565598883'}
# {'Time': '02:49', 'Track Title': 'Justin Bieber Ft. Ludacris Usher Snoop Dogg - Peaches Remix', 'Track ID': '1963189057658906006'}
# {'Time': '02:49', 'Track Title': 'KING KAKA - MANIFEST FT. NVIIRI THE STORYTELLER', 'Track ID': '1908741286632716335'}
# {'Time': '02:48', 'Track Title': 'Daliwonga - Abo Mvelo (Visualizer) ft. Mellow Sleazy and M.J', 'Track ID': '2124914129543070414'}
# {'Time': '02:45', 'Track Title': 'Crunch Time Hits', 'Track ID': '323474286861774330'}
# {'Time': '02:43', 'Track Title': 'Meek Mill - Dangerous ft. Jeremih and Pnb Rock', 'Track ID': '793009351516528966'}
# {'Time': '02:40', 'Track Title': 'Jhené Aiko - Lead the Way (From Raya and the Last Dragon)', 'Track ID': '2234143877188656301'}
# {'Time': '02:36', 'Track Title': 'TONES AND I - FLY AWAY', 'Track ID': '288412729618131198'}
# {'Time': '02:33', 'Track Title': 'Lie To Me - Karun Blocka Beats', 'Track ID': '971992676707489261'}
# {'Time': '02:30', 'Track Title': 'ArrDee - Oliver Twist GRM Daily', 'Track ID': '1458768308838636944'}
# {'Time': '02:26', 'Track Title': 'Wisin Jhay Cortez Ozuna - Emojis de Corazones ft. Los Legendarios', 'Track ID': '594077217112736119'}
# {'Time': '02:23', 'Track Title': 'Deno - Drizzy GRM Daily', 'Track ID': '1008865732675642912'}
# {'Time': '02:20', 'Track Title': 'Ruger - Useless', 'Track ID': '882342800986607379'}
# {'Time': '02:17', 'Track Title': 'Marshmello x Jonas Brothers - Leave Before You Love Me', 'Track ID': '1963171460897387007'}
# {'Time': '02:13', 'Track Title': 'Calvin Harris Dua Lipa Young Thug - Potion', 'Track ID': '1746998808420683773'}
# {'Time': '02:10', 'Track Title': 'Sauti Sol - Still The One', 'Track ID': '1441263483850791778'}
# {'Time': '02:07', 'Track Title': 'Patoranking - Kolo Kolo Feat. Diamond Platnumz', 'Track ID': '1891149220003037530'}

# %% [markdown]
# ### Export Tracklist to csv

# %%
import pandas as pd
# Directory
directory = 'reports'

# Filename with timestamp
timestamp = datetime.now().strftime('%Y-%m-%d_%H:%M:%S')
filename = f'Full_Tracklist_{timestamp}.csv'
file_path = os.path.join(directory, filename)

# Ensure that the directory exists
os.makedirs(directory, exist_ok=True)

# Converting to Pandas df and saving
df = pd.DataFrame(track_list)
df.to_csv(file_path, index=False)

print(f'CSV file saved to {file_path}')
# Out:
# CSV file saved to reports/Full_Tracklist_2025-01-27_14:28:21.csv

# %% [markdown]
# ### Extract music from the last hour, two hours e.t.c

# %% [markdown]
# #### a) First of all we need to get the time range for the whole tracklist

# %%
from datetime import datetime

def get_time_range(track_list):
    """
    Get the earliest and latest times in the track list.
    
    :param track_list: List of dictionaries containing track details and times.
    :return: Tuple of (earliest_time, latest_time) in 'HH:MM' format.
    """
    earliest_time = None
    latest_time = None

    # Loop through the track list to check all times
    for track in track_list:
        track_time = track["Time"]

        # If track_time is 'Live', use the current time
        if track_time == 'Live':
            track_time = datetime.now().strftime("%H:%M")

        try:
            # Convert track time to a datetime object
            track_dt = datetime.strptime(track_time, "%H:%M")

            # Update the earliest and latest times
            if earliest_time is None or track_dt < earliest_time:
                earliest_time = track_dt
            if latest_time is None or track_dt > latest_time:
                latest_time = track_dt
        except ValueError:
            # Skip tracks with invalid time data
            print(f"Skipping track with invalid time data: {track['Track Title']} ({track_time})")

    # Return the times in 'HH:MM' format
    return earliest_time.strftime("%H:%M") if earliest_time else None, latest_time.strftime("%H:%M") if latest_time else None

# %% [markdown]
# - Print the time range from fetched data

# %%
print(f'The time range for this tracklist is: {get_time_range(track_list)}')
# Out:
# The time range for this tracklist is: ('02:07', '14:29')

# %% [markdown]
# ### b) Filter tracks from the last x amount of hours

# %%
from datetime import datetime, timedelta

def get_recent_tracks(track_list, hours=1):
    """
    Extracts tracks from the last 'hours' from the given track list.
    
    :param track_list: List of dictionaries with keys: "Track Title", "Time", "Track ID".
    :param hours: Number of past hours to filter tracks (default: 1).
    :return: Filtered list of track dictionaries.
    """
    recent_tracks = []
    current_time = datetime.now()
    cutoff_time = current_time - timedelta(hours=hours)

    for track in track_list:
        track_title = track["Track Title"]
        track_time = track["Time"]

        # Handle "Live" as current time
        if track_time == "Live":
            track_time = current_time.strftime("%H:%M")

        try:
            # Parse time without assuming the date
            parsed_time = datetime.strptime(track_time, "%H:%M").time()
            
            # Create candidate datetime for today and yesterday
            today_date = current_time.date()
            candidate_dt_today = datetime.combine(today_date, parsed_time)
            candidate_dt_yesterday = candidate_dt_today - timedelta(days=1)

            # Check which candidate is within the cutoff window
            if candidate_dt_today <= current_time and candidate_dt_today >= cutoff_time:
                valid_dt = candidate_dt_today
            elif candidate_dt_yesterday >= cutoff_time:
                valid_dt = candidate_dt_yesterday
            else:
                continue  # Track is outside the window

            recent_tracks.append({
                "Time": track_time,
                "Track Title": track_title,
                "Track ID": track["Track ID"]
            })

        except ValueError:
            print(f"Skipping invalid time format: {track_title} ({track_time})")

    return recent_tracks, hours

# %% [markdown]
# - print tracks from the set period using the set time

# %%
last_x_hours = 3 
Recent_tracks = get_recent_tracks(track_list,hours = last_x_hours )

# %% [markdown]
# - Save the output of the most tracks from the recent hours into a csv file

# %%
# import pandas as pd
# Directory
directory = 'reports'

# Filename with timestamp
timestamp = datetime.now().strftime('%Y-%m-%d_%H:%M:%S')
filename = f'Recent_{last_x_hours}H_tracks_{timestamp}.csv'
file_path = os.path.join(directory, filename)

# Ensure that the directory exists
os.makedirs(directory, exist_ok=True)

# Getting recent tracks (using only the list of tracks, not the tuple)
recent_tracks, _ = get_recent_tracks(track_list, hours=last_x_hours)

# Converting to Pandas df and saving
df = pd.DataFrame(recent_tracks)
df.to_csv(file_path, index=False)

print(f'CSV file saved to {file_path}')
# Out:
# CSV file saved to reports/Recent_3H_tracks_2025-01-26_16:41:52.csv

# %% [markdown]
# #### b) Filter tracks from a date range start_time to end_time

# %%
from datetime import datetime

def get_tracks_in_range(track_list, start_time, end_time):
    """
    Extracts tracks within a specific time range from the track list.
    
    :param track_list: List of dictionaries containing track details and times.
    :param start_time: Start time in 'HH:MM' format.
    :param end_time: End time in 'HH:MM' format.
    :return: List of dictionaries with track details.
    """
    tracks_in_range = []

    # Convert start and end times to datetime objects
    start_dt = datetime.strptime(start_time, "%H:%M")
    end_dt = datetime.strptime(end_time, "%H:%M")

    for track in track_list:
        track_title = track["Track Title"]
        track_time = track["Time"]

        # Check if track_time is 'Live' (currently playing)
        if track_time == 'Live':
            track_time = datetime.now().strftime("%H:%M")  # Convert 'Live' to current time in HH:MM format

        try:
            # Convert track time to a datetime object
            track_dt = datetime.strptime(track_time, "%H:%M")

            # Check if the track falls within the given time range
            if start_dt <= track_dt <= end_dt:
                tracks_in_range.append({
                    "Time": track_time,
                    "Track Title": track_title,
                    "Track ID": track["Track ID"]
                })
        except ValueError:
            # Skip tracks with invalid time data
            print(f"Skipping track with invalid time data: {track_title} ({track_time})")

    return tracks_in_range

# %% [markdown]
# - Initialize start_date and end_date

# %%
start_time_x = '06:00'
end_time_y = '10:00'
get_tracks_in_range(track_list, start_time_x,end_time_y)
# Out:
# [{'Time': '09:58',
#   'Track Title': 'Don t Clean - Bryson Tiller',
#   'Track ID': '666134831798028050'},
#  {'Time': '09:55',
#   'Track Title': 'ZieZie - Blessed G46 GRIME',
#   'Track ID': '738192331242851678'},
#  {'Time': '09:52',
#   'Track Title': 'Wes Nelson - Nice To Meet Ya (Lyrics) ft Yxng Bane',
#   'Track ID': '449979559122487605'},
#  {'Time': '09:26',
#   'Track Title': 'Cheat Codes - Do It All Over (feat. Marc E. Bassy)',
#   'Track ID': '1152998456193454283'},
#  {'Time': '09:23',
#   'Track Title': 'Diamond Platnumz ft Focalistic Costa Titch Pabi Cooper - Fresh (',
#   'Track ID': '2269029313849538892'},
#  {'Time': '09:20',
#   'Track Title': 'One Acen - Monogram ft. Wauve',
#   'Track ID': '1441228879897058741'},
#  {'Time': '09:17',
#   'Track Title': 'Adekunle Gold - Okay (Afro Pop Vol. 1)',
#   'Track ID': '2161857512078794801'},
#  {'Time': '09:14',
#   'Track Title': 'Rema - Bounce',
#   'Track ID': '1152998485684728645'},
#  {'Time': '09:11',
#   'Track Title': 'NSG Ft. LD - Roadblock',
#   'Track ID': '35243914392981027'},
#  {'Time': '09:07',
#   'Track Title': 'Fireboy DML Ed Sheeran - Peru',
#   'Track ID': '1332315694376141878'},
#  {'Time': '09:03',
#   'Track Title': 'D-Block Europe - Ferrari Horses ft. Raye',
#   'Track ID': '810267521133078020'},
#  {'Time': '09:00',
#   'Track Title': 'Ariana Grande - One last time (Amapiano Remix)By La Mayor',
#   'Track ID': '738209730336986045'},
#  {'Time': '08:57',
#   'Track Title': 'Stefflon Don - Can t Let You Go (Lyrics)',
#   'Track ID': '1458768225231569454'},
#  {'Time': '08:54',
#   'Track Title': 'Yxng Bane ft. WSTRN - Fine Wine (Remix) GRM Daily',
#   'Track ID': '899934666598389685'},
#  {'Time': '08:50',
#   'Track Title': 'Headie One - Siberia ft. Burna Boy',
#   'Track ID': '2161787198462941046'},
#  {'Time': '08:47',
#   'Track Title': 'Wauve - Monzo ft. One Acen',
#   'Track ID': '1980798877648308356'},
#  {'Time': '08:40',
#   'Track Title': 'Bayanni - Ta Ta Ta (Official Lyric Audio)',
#   'Track ID': '1332315832514073544'},
#  {'Time': '08:37',
#   'Track Title': 'Maroon 5 - Beautiful Mistakes ft. Megan Thee Stallion',
#   'Track ID': '216284949413964196'},
#  {'Time': '08:33',
#   'Track Title': 'DJ Snake Ozuna Megan Thee Stallion LISA of BLACKPINK - SG.wav',
#   'Track ID': '89691660975184574'},
#  {'Time': '08:30',
#   'Track Title': 'Rema - Soundgasm (MAX WALLIN TOUCH)',
#   'Track ID': '1729424187542879007'},
#  {'Time': '08:26',
#   'Track Title': 'Jocelyn Alice - Feels Right (Galloway Remix)',
#   'Track ID': '1225108262845568025'},
#  {'Time': '08:23',
#   'Track Title': 'City Girls Fivio Foreign - Top Notch',
#   'Track ID': '2017707347510678428'},
#  {'Time': '08:19',
#   'Track Title': 'Dave Stormzy - Clash',
#   'Track ID': '1945737621074297053'},
#  {'Time': '08:19',
#   'Track Title': 'Lauv - 26',
#   'Track ID': '2052926881562397537'},
#  {'Time': '08:14',
#   'Track Title': 'Major Lazer - C est Cuit (feat. Aya Nakamura Swae Lee)',
#   'Track ID': '738209940860823708'},
#  {'Time': '08:11',
#   'Track Title': 'Blaq Diamond - SummerYoMuthi',
#   'Track ID': '233789136301771862'},
#  {'Time': '08:09',
#   'Track Title': 'INNA - Always On My Mind (Lyrics)',
#   'Track ID': '1225144151901805036'},
#  {'Time': '08:04',
#   'Track Title': '24kGoldn - Coco (Clean Lyrics) ft. DaBaby',
#   'Track ID': '377921972735235795'},
#  {'Time': '08:01',
#   'Track Title': 'Tems- The Key',
#   'Track ID': '2197006731049085016'},
#  {'Time': '07:14',
#   'Track Title': 'Davido - Jowo NR Xtendz',
#   'Track ID': '1152998448626177596'},
#  {'Time': '07:14',
#   'Track Title': 'Sauti Sol - Rhumba Japani ft Kaskazini Bensoul Nviiri Xenia Manasseh Okello Max Nairobi Ho',
#   'Track ID': '1602900993913347031'},
#  {'Time': '07:11',
#   'Track Title': 'Diane Warren Rita Ora Sofía Reyes Reik - Seaside',
#   'Track ID': '2035246685143211178'},
#  {'Time': '07:09',
#   'Track Title': 'WizKid - Essence (Audio) ft. Tems',
#   'Track ID': '467624467706850916'},
#  {'Time': '07:05',
#   'Track Title': 'J.Derobie Gold Up - Day Night Official Lyrics Video',
#   'Track ID': '1332280454922988574'},
#  {'Time': '07:01',
#   'Track Title': 'Bensoul x Bien - Thick Thighs',
#   'Track ID': '179359070883021097'},
#  {'Time': '06:57',
#   'Track Title': 'Ava Max - My Head My Heart',
#   'Track ID': '216548825543248714'},
#  {'Time': '06:57',
#   'Track Title': 'MIST feat Burna Boy - Rollin',
#   'Track ID': '1980834027270609897'},
#  {'Time': '06:54',
#   'Track Title': 'DJ Snake Selena Gomez - Selfish Love (Lyrics )',
#   'Track ID': '1891131433735687053'},
#  {'Time': '06:51',
#   'Track Title': 'Darkoo - Rover (Keys to my rover)',
#   'Track ID': '1404337881203476442'},
#  {'Time': '06:47',
#   'Track Title': 'M.anifest - Game Over ft. Adekunle Gold',
#   'Track ID': '1513268976329909555'},
#  {'Time': '06:44',
#   'Track Title': 'Doja Cat - Woman (Mica Remix)',
#   'Track ID': '1153016144237692820'},
#  {'Time': '06:42',
#   'Track Title': 'Headie One - Everything Nice (feat. Haile) G46 GRIME',
#   'Track ID': '467589369385754801'},
#  {'Time': '06:37',
#   'Track Title': 'MAGGIE WA NYUMBANI - NDOVU KUU X BIEN THE BALDMAN',
#   'Track ID': '161731742428978777'},
#  {'Time': '06:21',
#   'Track Title': 'Black Sherif - Kwaku The Traveller (Radio Clean)',
#   'Track ID': '1513251417634161738'},
#  {'Time': '06:18',
#   'Track Title': 'CLEAN Central Cee - Khabib',
#   'Track ID': '539647043043446252'},
#  {'Time': '06:18',
#   'Track Title': 'Major Lazer feat. Alessia Cara - Hell and High Water',
#   'Track ID': '1026440254678705995'},
#  {'Time': '06:16',
#   'Track Title': 'Galantis x Throttle - Tell Me You Love Me',
#   'Track ID': '1170537471180084891'},
#  {'Time': '06:13',
#   'Track Title': 'Adekunle Gold - It Is What It Is',
#   'Track ID': '1441193699923542436'},
#  {'Time': '06:10',
#   'Track Title': 'Joeboy - Contour (Lyric Visualizer)',
#   'Track ID': '2269029366337962777'},
#  {'Time': '06:06',
#   'Track Title': 'Mannywellz ft Tems - Peace (Lyrics)',
#   'Track ID': '1801516789807321156'},
#  {'Time': '06:03',
#   'Track Title': 'Chunkz X Filly - Hold',
#   'Track ID': '899934842125741527'}]

# %% [markdown]
# - Save the outputs of the time range into a csv file

# %%
# import pandas as pd
# Directory
directory = 'reports'

# Filename with timestamp
timestamp = datetime.now().strftime('%Y-%m-%d_%H:%M:%S')
filename = f'Time_range_{start_time_x}-{end_time_y}H_tracks_{timestamp}.csv'
file_path = os.path.join(directory, filename)

# Ensure that the directory exists
os.makedirs(directory, exist_ok=True)

# Getting recent tracks (usin# import pandas as pd
# Directory
directory = 'reports'

# Filename with timestamp
timestamp = datetime.now().strftime('%Y-%m-%d_%H:%M:%S')
filename = f'Time_range_{start_time_x}-{end_time_y}H_tracks_{timestamp}.csv'
file_path = os.path.join(directory, filename)

# Ensure that the directory exists
os.makedirs(directory, exist_ok=True)

# Getting recent tracks (using only the list of tracks, not the tuple)
time_range_tracks = get_tracks_in_range(track_list, start_time_x,end_time_y)

# Converting to Pandas df and saving
df = pd.DataFrame(time_range_tracks)
df.to_csv(file_path, index=False)

# print(f'CSV file saved to {file_path}') only the list of tracks, not the tuple)
time_range_tracks = get_tracks_in_range(track_list, start_time_x,end_time_y)

# Converting to Pandas df and saving
df = pd.DataFrame(time_range_tracks)
df.to_csv(file_path, index=False)

print(f'CSV file saved to {file_path}')
# Out:
# CSV file saved to reports/Time_range_06:00-10:00H_tracks_2025-01-27_14:31:20.csv

# %% [markdown]
# ### Spotify’s search API expects a query in this format: 'https://api.spotify.com/v1/search?q=<query>&type=track'

# %%
import re
# clean the title
def clean_title(title):
    """Remove noise like (Lyrics), codes, etc."""
    title = re.sub(r'\([^)]*\)|\b\d+.*$', '', title)  # Remove () content and codes
    title = re.sub(r'\s+', ' ', title).strip()
    return title

# Parsing the track_list to a spotify query
def parse_tracklist_to_spotify_query(track_list):
    spotify_queries = []
    for track in track_list:
        track_title = track.get("Track Title", "Unknown Title")
        artist = track.get("Artist", "").strip()

        # Clean the title first
        track_title = clean_title(track_title)

        # Extract artist from title if missing
        if not artist:
            # Split by common delimiters (e.g., " - ", "feat", "ft", "&")
            parts = re.split(r'\s+[-–—]+\s+| feat\b| ft\b| & |/', track_title, flags=re.IGNORECASE)
            possible_artist = parts[0].strip() if parts else "Unknown Artist"
            # Allow apostrophes, hyphens, and & in artist names
            possible_artist = re.sub(r'[^a-zA-Z\s\'\-&]', '', possible_artist)
            artist = possible_artist if possible_artist else "Unknown Artist"

        # Extract featured artists from title (e.g., "Song (feat. Artist)")
        featured = re.findall(r'\(feat[.\s]*([^)]+)\)', track_title, re.IGNORECASE)
        if featured:
            featured_artist = re.sub(r'[^a-zA-Z\s\'\-&]', '', featured[0].strip())
            artist += f", {featured_artist}"

        # Final cleanup
        artist = re.sub(r'\s+', ' ', artist).strip()
        query = f"track:{track_title} artist:{artist}"
        spotify_queries.append(query)

    return spotify_queries

# %%
raw_data = parse_tracklist_to_spotify_query(time_range_tracks)
print(raw_data)
# Out:
# ['track:Don t Clean - Bryson Tiller artist:Don t Clean', 'track:ZieZie - Blessed G46 GRIME artist:ZieZie', 'track:Wes Nelson - Nice To Meet Ya ft Yxng Bane artist:Wes Nelson', 'track:Cheat Codes - Do It All Over artist:Cheat Codes', 'track:Diamond Platnumz ft Focalistic Costa Titch Pabi Cooper - Fresh ( artist:Diamond Platnumz', 'track:One Acen - Monogram ft. Wauve artist:One Acen', 'track:Adekunle Gold - Okay artist:Adekunle Gold', 'track:Rema - Bounce artist:Rema', 'track:NSG Ft. LD - Roadblock artist:NSG', 'track:Fireboy DML Ed Sheeran - Peru artist:Fireboy DML Ed Sheeran', 'track:D-Block Europe - Ferrari Horses ft. Raye artist:D-Block Europe', 'track:Ariana Grande - One last time By La Mayor artist:Ariana Grande', 'track:Stefflon Don - Can t Let You Go artist:Stefflon Don', 'track:Yxng Bane ft. WSTRN - Fine Wine GRM Daily artist:Yxng Bane', 'track:Headie One - Siberia ft. Burna Boy artist:Headie One', 'track:Wauve - Monzo ft. One Acen artist:Wauve', 'track:Bayanni - Ta Ta Ta artist:Bayanni', 'track:Maroon artist:Maroon', 'track:DJ Snake Ozuna Megan Thee Stallion LISA of BLACKPINK - SG.wav artist:DJ Snake Ozuna Megan Thee Stallion LISA of BLACKPINK', 'track:Rema - Soundgasm artist:Rema', 'track:Jocelyn Alice - Feels Right artist:Jocelyn Alice', 'track:City Girls Fivio Foreign - Top Notch artist:City Girls Fivio Foreign', 'track:Dave Stormzy - Clash artist:Dave Stormzy', 'track:Lauv - artist:Lauv -', 'track:Major Lazer - C est Cuit artist:Major Lazer', 'track:Blaq Diamond - SummerYoMuthi artist:Blaq Diamond', 'track:INNA - Always On My Mind artist:INNA', 'track: artist:Unknown Artist', 'track:Tems- The Key artist:Tems- The Key', 'track:Davido - Jowo NR Xtendz artist:Davido', 'track:Sauti Sol - Rhumba Japani ft Kaskazini Bensoul Nviiri Xenia Manasseh Okello Max Nairobi Ho artist:Sauti Sol', 'track:Diane Warren Rita Ora Sofía Reyes Reik - Seaside artist:Diane Warren Rita Ora Sofa Reyes Reik', 'track:WizKid - Essence ft. Tems artist:WizKid', 'track:J.Derobie Gold Up - Day Night Official Lyrics Video artist:JDerobie Gold Up', 'track:Bensoul x Bien - Thick Thighs artist:Bensoul x Bien', 'track:Ava Max - My Head My Heart artist:Ava Max', 'track:MIST feat Burna Boy - Rollin artist:MIST', 'track:DJ Snake Selena Gomez - Selfish Love artist:DJ Snake Selena Gomez', 'track:Darkoo - Rover artist:Darkoo', 'track:M.anifest - Game Over ft. Adekunle Gold artist:Manifest', 'track:Doja Cat - Woman artist:Doja Cat', 'track:Headie One - Everything Nice G46 GRIME artist:Headie One', 'track:MAGGIE WA NYUMBANI - NDOVU KUU X BIEN THE BALDMAN artist:MAGGIE WA NYUMBANI', 'track:Black Sherif - Kwaku The Traveller artist:Black Sherif', 'track:CLEAN Central Cee - Khabib artist:CLEAN Central Cee', 'track:Major Lazer feat. Alessia Cara - Hell and High Water artist:Major Lazer', 'track:Galantis x Throttle - Tell Me You Love Me artist:Galantis x Throttle', 'track:Adekunle Gold - It Is What It Is artist:Adekunle Gold', 'track:Joeboy - Contour artist:Joeboy', 'track:Mannywellz ft Tems - Peace artist:Mannywellz', 'track:Chunkz X Filly - Hold artist:Chunkz X Filly']

# %%
for x in raw_data:
    print(x)
# Out:
# track:Don t Clean - Bryson Tiller artist:Don t Clean
# track:ZieZie - Blessed G46 GRIME artist:ZieZie
# track:Wes Nelson - Nice To Meet Ya ft Yxng Bane artist:Wes Nelson
# track:Cheat Codes - Do It All Over artist:Cheat Codes
# track:Diamond Platnumz ft Focalistic Costa Titch Pabi Cooper - Fresh ( artist:Diamond Platnumz
# track:One Acen - Monogram ft. Wauve artist:One Acen
# track:Adekunle Gold - Okay artist:Adekunle Gold
# track:Rema - Bounce artist:Rema
# track:NSG Ft. LD - Roadblock artist:NSG
# track:Fireboy DML Ed Sheeran - Peru artist:Fireboy DML Ed Sheeran
# track:D-Block Europe - Ferrari Horses ft. Raye artist:D-Block Europe
# track:Ariana Grande - One last time By La Mayor artist:Ariana Grande
# track:Stefflon Don - Can t Let You Go artist:Stefflon Don
# track:Yxng Bane ft. WSTRN - Fine Wine GRM Daily artist:Yxng Bane
# track:Headie One - Siberia ft. Burna Boy artist:Headie One
# track:Wauve - Monzo ft. One Acen artist:Wauve
# track:Bayanni - Ta Ta Ta artist:Bayanni
# track:Maroon artist:Maroon
# track:DJ Snake Ozuna Megan Thee Stallion LISA of BLACKPINK - SG.wav artist:DJ Snake Ozuna Megan Thee Stallion LISA of BLACKPINK
# track:Rema - Soundgasm artist:Rema
# track:Jocelyn Alice - Feels Right artist:Jocelyn Alice
# track:City Girls Fivio Foreign - Top Notch artist:City Girls Fivio Foreign
# track:Dave Stormzy - Clash artist:Dave Stormzy
# track:Lauv - artist:Lauv -
# track:Major Lazer - C est Cuit artist:Major Lazer
# track:Blaq Diamond - SummerYoMuthi artist:Blaq Diamond
# track:INNA - Always On My Mind artist:INNA
# track: artist:Unknown Artist
# track:Tems- The Key artist:Tems- The Key
# track:Davido - Jowo NR Xtendz artist:Davido
# track:Sauti Sol - Rhumba Japani ft Kaskazini Bensoul Nviiri Xenia Manasseh Okello Max Nairobi Ho artist:Sauti Sol
# track:Diane Warren Rita Ora Sofía Reyes Reik - Seaside artist:Diane Warren Rita Ora Sofa Reyes Reik
# track:WizKid - Essence ft. Tems artist:WizKid
# track:J.Derobie Gold Up - Day Night Official Lyrics Video artist:JDerobie Gold Up
# track:Bensoul x Bien - Thick Thighs artist:Bensoul x Bien
# track:Ava Max - My Head My Heart artist:Ava Max
# track:MIST feat Burna Boy - Rollin artist:MIST
# track:DJ Snake Selena Gomez - Selfish Love artist:DJ Snake Selena Gomez
# track:Darkoo - Rover artist:Darkoo
# track:M.anifest - Game Over ft. Adekunle Gold artist:Manifest
# track:Doja Cat - Woman artist:Doja Cat
# track:Headie One - Everything Nice G46 GRIME artist:Headie One
# track:MAGGIE WA NYUMBANI - NDOVU KUU X BIEN THE BALDMAN artist:MAGGIE WA NYUMBANI
# track:Black Sherif - Kwaku The Traveller artist:Black Sherif
# track:CLEAN Central Cee - Khabib artist:CLEAN Central Cee
# track:Major Lazer feat. Alessia Cara - Hell and High Water artist:Major Lazer
# track:Galantis x Throttle - Tell Me You Love Me artist:Galantis x Throttle
# track:Adekunle Gold - It Is What It Is artist:Adekunle Gold
# track:Joeboy - Contour artist:Joeboy
# track:Mannywellz ft Tems - Peace artist:Mannywellz
# track:Chunkz X Filly - Hold artist:Chunkz X Filly

# %%
import re
from thefuzz import fuzz, process
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import unicodedata
import logging


import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Set up Spotify authentication
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id=os.getenv("SPOTIFY_CLIENT_ID"),
    client_secret=os.getenv("SPOTIFY_CLIENT_SECRET"),
    redirect_uri="http://localhost:8080/callback",
    scope="playlist-modify-public"
))

class SpotifyTrackMatcher:
    def __init__(self, sp_client):
        """
        Initialize the Spotify Track Matcher with enhanced search capabilities.
        
        :param sp_client: Authenticated Spotify client
        """
        self.sp = sp_client
        self.logger = logging.getLogger(__name__)
        logging.basicConfig(level=logging.INFO)

    def normalize_text(self, text):
        """
        Comprehensive text normalization:
        1. Convert to lowercase
        2. Remove diacritical marks
        3. Remove extra whitespaces
        4. Handle special characters
        
        :param text: Input text to normalize
        :return: Normalized text
        """
        # Remove diacritical marks
        text = unicodedata.normalize('NFKD', text).encode('ASCII', 'ignore').decode('ASCII')
        
        # Lowercase and remove extra spaces
        return re.sub(r'\s+', ' ', text.lower()).strip()

    def extract_canonical_features(self, title):
        """
        Extract canonical features from track title:
        1. Remove parenthetical info 
        2. Remove common words
        3. Extract core title elements
        
        :param title: Original track title
        :return: Canonical title features
        """
        # Remove parenthetical content and metadata
        title = re.sub(r'\(.*?\)|\[.*?\]', '', title)
        
        # Remove common words and prefixes
        title = re.sub(r'\b(the|a|an|remix|remaster|live)\b', '', title, flags=re.IGNORECASE)
        
        return self.normalize_text(title)

    def advanced_artist_matching(self, track_candidates, search_artist):
        """
        Advanced artist matching with multiple strategies:
        1. Full artist name match
        2. Partial artist name match
        3. Multiple artist combinations
        
        :param track_candidates: List of track candidates
        :param search_artist: Artist search string
        :return: Best matching track
        """
        normalized_search_artist = self.normalize_text(search_artist)
        
        # Split potential multiple artists
        potential_artists = re.split(r'[&,x]|\bft\.|\bfeat\.', search_artist, flags=re.IGNORECASE)
        potential_artists = [self.normalize_text(artist.strip()) for artist in potential_artists]
        
        best_match = None
        best_score = 0
        
        for track in track_candidates:
            # Extract track artists
            track_artists = [self.normalize_text(artist['name']) for artist in track['artists']]
            
            # Score calculation with multiple strategies
            artist_match_score = max([
                max([fuzz.ratio(pa, ta) for ta in track_artists]) 
                for pa in potential_artists
            ])
            
            # Weighted scoring
            track_score = (
                0.6 * artist_match_score + 
                0.4 * fuzz.ratio(
                    self.extract_canonical_features(track['name']),
                    self.extract_canonical_features(search_artist)
                )
            )
            
            if track_score > best_score:
                best_score = track_score
                best_match = track
        
        # Confidence threshold
        return best_match if best_score > 70 else None

    def search_track(self, title, artist, max_results=20):
        """
        Comprehensive track search with multiple fallback strategies
        
        :param title: Track title
        :param artist: Artist name
        :param max_results: Maximum search results to consider
        :return: Best matching track URI or None
        """
        # Normalize inputs
        normalized_title = self.normalize_text(title)
        normalized_artist = self.normalize_text(artist)
        
        # Search strategies in order of specificity
        search_strategies = [
            f"track:{title} artist:{artist}",  # Most specific
            f"track:{normalized_title}",       # Title-only fallback
            f"artist:{normalized_artist}"      # Artist-only fallback
        ]
        
        for strategy in search_strategies:
            try:
                results = self.sp.search(q=strategy, type='track', limit=max_results)
                track_candidates = results['tracks']['items']
                
                if track_candidates:
                    # Advanced matching
                    best_match = self.advanced_artist_matching(track_candidates, artist)
                    
                    if best_match:
                        self.logger.info(f"Matched: {best_match['name']} - {best_match['artists'][0]['name']}")
                        return best_match['uri']
            
            except Exception as e:
                self.logger.error(f"Search error with strategy {strategy}: {e}")
        
        self.logger.warning(f"No match found for {title} by {artist}")
        return None

def parse_and_match_spotify(sp_client, raw_data):
    """
    Process multiple tracks with enhanced matching
    
    :param sp_client: Spotify client
    :param raw_data: Raw track data
    :return: List of matched track URIs
    """
    matcher = SpotifyTrackMatcher(sp_client)
    uris = []
    
    for entry in raw_data:
        try:
            # Split and clean entry similar to original implementation
            title, artist = parse_entry(entry)
            
            uri = matcher.search_track(title, artist)
            if uri:
                uris.append(uri)
        
        except Exception as e:
            matcher.logger.error(f"Error processing entry {entry}: {e}")
    
    return uris

def parse_entry(entry):
    """
    Parse raw entry into title and artist
    
    :param entry: Raw track entry
    :return: Tuple of (title, artist)
    """
    # Implement similar parsing logic to original code
    # This is a placeholder and should match your specific input format
    parts = entry.split("artist:")
    title = parts[0].replace("track:", "").strip()
    artist = parts[1].strip() if len(parts) > 1 else "Unknown"
    
    return title, artist

# %%
track_uris = parse_and_match_spotify(sp, raw_data)
print(f"\nA total of {
    len(track_uris)} out of the {len(raw_data)} played on Radio were matched on Spotify. \nThat's {
        len(track_uris)/len(raw_data)*100:.2F}% of the songs.\n")
# print("Matched URIs:", track_uris)
# Out:
# WARNING:__main__:No match found for Don t Clean - Bryson Tiller by Don t Clean
# INFO:__main__:Matched: Fine Girl - ZieZie
# INFO:__main__:Matched: Say Nothing - Wes Nelson
# INFO:__main__:Matched: Yo Bunny - Cheat Codes Remix - prodbycpkshawn
# INFO:__main__:Matched: African Beauty (feat. Omarion) - Diamond Platnumz
# INFO:__main__:Matched: Hate on Me (feat. One Acen) - Tion Wayne
# INFO:__main__:Matched: Done For Me (feat. Adekunle Gold) - Fridayy
# INFO:__main__:Matched: OZEBA - Rema
# INFO:__main__:Matched: Nyash (Current & Savings) - NSG
# WARNING:__main__:No match found for Fireboy DML Ed Sheeran - Peru by Fireboy DML Ed Sheeran
# INFO:__main__:Matched: Rocket Science - Clavish
# INFO:__main__:Matched: Bang Bang - Jessie J
# INFO:__main__:Matched: The Reason Why - JP Cooper
# INFO:__main__:Matched: Shape of You - Yxng Bane Remix - Ed Sheeran
# INFO:__main__:Matched: The One - Headie One
# INFO:__main__:Matched: Pavements - Wauve
# INFO:__main__:Matched: Bukhaar - Aroob Khan
# INFO:__main__:Matched: Marooned - Maroon
# WARNING:__main__:No match found for DJ Snake Ozuna Megan Thee Stallion LISA of BLACKPINK - SG.wav by DJ Snake Ozuna Megan Thee Stallion LISA of BLACKPINK
# INFO:__main__:Matched: OZEBA - Rema
# INFO:__main__:Matched: Radio Silence - Ryan Riback Remix - R3HAB
# WARNING:__main__:No match found for City Girls Fivio Foreign - Top Notch by City Girls Fivio Foreign
# WARNING:__main__:No match found for Dave Stormzy - Clash by Dave Stormzy
# WARNING:__main__:No match found for Lauv - by Lauv -
# INFO:__main__:Matched: C'est Cuit - Major Lazer VIP Remix - Major Lazer
# INFO:__main__:Matched: Impi Yothando - Blaq Diamond
# INFO:__main__:Matched: Amazing - INNA
# INFO:__main__:Matched: Unknown Track - Unknown Artist
# WARNING:__main__:No match found for Tems- The Key by Tems- The Key
# INFO:__main__:Matched: UNAVAILABLE (feat. Musa Keys) - Davido
# INFO:__main__:Matched: Still the one - Sauti Sol
# WARNING:__main__:No match found for Diane Warren Rita Ora Sofía Reyes Reik - Seaside by Diane Warren Rita Ora Sofa Reyes Reik
# INFO:__main__:Matched: This Kind Luv - Patoranking
# WARNING:__main__:No match found for J.Derobie Gold Up - Day Night Official Lyrics Video by JDerobie Gold Up
# INFO:__main__:Matched: National Treasure (feat. Xenia Manasseh and Vallerie Muthoni) - Bien-Aime Baraza
# WARNING:__main__:No match found for Ava Max - My Head My Heart by Ava Max
# INFO:__main__:Matched: Fisherman (feat. MoStack & MIST) - J Hus
# WARNING:__main__:No match found for DJ Snake Selena Gomez - Selfish Love by DJ Snake Selena Gomez
# INFO:__main__:Matched: Right Now - Darkoo
# INFO:__main__:Matched: Another Story (feat. M.anifest) - Burna Boy
# INFO:__main__:Matched: You Right - Doja Cat
# INFO:__main__:Matched: The One - Headie One
# WARNING:__main__:No match found for MAGGIE WA NYUMBANI - NDOVU KUU X BIEN THE BALDMAN by MAGGIE WA NYUMBANI
# INFO:__main__:Matched: Rebel Music - Black Sherif
# WARNING:__main__:No match found for CLEAN Central Cee - Khabib by CLEAN Central Cee
# INFO:__main__:Matched: Mwaki - Major Lazer Remix - Zerb
# WARNING:__main__:No match found for Galantis x Throttle - Tell Me You Love Me by Galantis x Throttle
# INFO:__main__:Matched: Done For Me (feat. Adekunle Gold) - Fridayy
# INFO:__main__:Matched: Nobody - DJ Neptune
# INFO:__main__:Matched: Your well - Mannywellz
# WARNING:__main__:No match found for Chunkz X Filly - Hold by Chunkz X Filly
# A total of 36 out of the 51 played on Radio were matched on Spotify.
# That's 70.59% of the songs.

# %% [markdown]
# - Save matched tracks to csv file

# %%
# import os
# import pandas as pd
# from datetime import datetime

# Directory
directory = 'reports'

# Filename with timestamp
timestamp = datetime.now().strftime('%Y-%m-%d_%H:%M:%S')
filename = f'Matched_Spotify_tracks_{timestamp}.csv'
file_path = os.path.join(directory, filename)

# Ensure that the directory exists
os.makedirs(directory, exist_ok=True)

# Convert the list of queries into a DataFrame
df = pd.DataFrame(track_uris, columns=["Spotify Query"])

# Save the DataFrame to a CSV file
df.to_csv(file_path, index=False)

print(f'CSV file saved to {file_path}')
# Out:
# CSV file saved to reports/Matched_Spotify_tracks_2025-01-26_19:18:33.csv

# %%
# Create a new playlist
playlist_name = f"Hits Radio {timestamp}"
user_id = sp.me()['id']
playlist = sp.user_playlist_create(user_id, playlist_name, public=True)

# Add tracks to the playlist
sp.playlist_add_items(playlist['uri'], track_uris)

print(f"Playlist {playlist_name} created with {len(track_uris)} tracks!")
# Out:
# Playlist Hits Radio 2025-01-27_14:31:20 created with 36 tracks!

# %%
# Create a new playlist with a description
timestamp = datetime.now().strftime('%Y-%m-%d_%H:%M:%S')
playlist_name = f"Hits Radio - Morning {timestamp}"
playlist_description = "A curated list of the latest hits on played on Hits Radio from 6-10am everyday, by David Kibet."

# Get the user ID
user_id = sp.me()['id']

# Create the playlist with a description
playlist = sp.user_playlist_create(user_id, playlist_name, public=True, description=playlist_description)

# Add tracks to the playlist
sp.playlist_add_items(playlist['uri'], track_uris)

print(f"Playlist '{playlist_name}' created with {len(track_uris)} tracks!")
# Out:
# Playlist 'Hits Radio - Morning 2025-01-26_19:18:56' created with 37 tracks!
